# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from datetime import datetime

# %%
btc = yf.download("BTC-USD", start="2018-01-01", end="2025-05-24")
btc.reset_index(inplace=True)
btc.columns = ['Date', 'Open', 'High', 'Low', 'Close', 'Volume']
btc.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#            Date           Open           High            Low          Close  \
# 2695 2025-05-19  105606.179688  107068.718750  102112.687500  106430.531250
# 2696 2025-05-20  106791.085938  107307.117188  104206.515625  105605.406250
# 2697 2025-05-21  109678.078125  110724.460938  106127.234375  106791.312500
# 2698 2025-05-22  111673.281250  111970.171875  109285.070312  109673.492188
# 2699 2025-05-23  107287.796875  111798.906250  106841.304688  111679.359375
#
#            Volume
# 2695  61761126647
# 2696  36515726122
# 2697  78086364051
# 2698  70157575642
# 2699  67548133399

# %%
print(btc.columns)
# Out:
# MultiIndex([(  'Date',        ''),
#             ( 'Close', 'BTC-USD'),
#             (  'High', 'BTC-USD'),
#             (   'Low', 'BTC-USD'),
#             (  'Open', 'BTC-USD'),
#             ('Volume', 'BTC-USD')],
#            names=['Price', 'Ticker'])

# %%
plt.figure(figsize=(14,6))
plt.plot(btc['Date'], btc['Close'], label='Precio de cierre BTC')
plt.title("Evolución histórica del precio de Bitcoin (2018–2025)")
plt.xlabel("Fecha")
plt.ylabel("USD")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Crear variable 'Days' para usar en la regresión
btc['Days'] = (btc['Date'] - btc['Date'].min()).dt.days

# Definir variables para modelo
X = btc[['Days']]
y = btc['Close']

# Entrenar modelo
model = LinearRegression()
model.fit(X, y)

# Predecir
btc['Predicted'] = model.predict(X)

# %%
plt.figure(figsize=(14,6))
plt.plot(btc['Date'], btc['Close'], label='Precio real')
plt.plot(btc['Date'], btc['Predicted'], label='Predicción lineal', linestyle='--')
plt.title("Predicción simple del precio de Bitcoin (Regresión lineal)")
plt.xlabel("Fecha")
plt.ylabel("USD")
plt.grid(True)
plt.legend()
plt.show()
